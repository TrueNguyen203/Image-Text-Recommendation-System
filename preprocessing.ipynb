# %%
from datasets import load_dataset
import pandas as pd
import re
from pydantic import BaseModel
from fastapi import FastAPI

ds = load_dataset("UniqueData/asos-e-commerce-dataset")

# %%
df = ds["train"].to_pandas()
df.head()
# Out:
#                                                  url  \
# 0  https://www.asos.com/stradivarius/stradivarius...
# 1  https://www.asos.com/stradivarius/stradivarius...
# 2  https://www.asos.com/asos-design/asos-design-l...
# 3  https://www.asos.com/new-look/new-look-trench-...
# 4  https://www.asos.com/stradivarius/stradivarius...
#
#                                              name  \
# 0                   New Look trench coat in camel
# 1                   New Look trench coat in camel
# 2                   New Look trench coat in camel
# 3                   New Look trench coat in camel
# 4  Stradivarius double breasted wool coat in grey
#
#                                                 size  \
# 0  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14 - Out of stoc...
# 1  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14 - Out of stoc...
# 2  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14 - Out of stoc...
# 3  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14 - Out of stoc...
# 4  XS - UK 6,S - UK 8,M - UK 10,L - UK 12,XL - UK 14
#
#                                          category  price    color  \
# 0                   New Look trench coat in camel  49.99  Neutral
# 1                   New Look trench coat in camel  49.99  Neutral
# 2                   New Look trench coat in camel  49.99  Neutral
# 3                   New Look trench coat in camel  49.99  Neutral
# 4  Stradivarius double breasted wool coat in grey  59.99     GREY
#
#            sku                                        description  \
# 0  126704571.0  [{'Product Details': 'Coats & Jackets by New L...
# 1  126704571.0  [{'Product Details': 'Coats & Jackets by New L...
# 2  126704571.0  [{'Product Details': 'Coats & Jackets by New L...
# 3  126704571.0  [{'Product Details': 'Coats & Jackets by New L...
# 4  123650194.0  [{'Product Details': 'Coats & Jackets by Strad...
#
#                                               images
# 0  ['https://images.asos-media.com/products/new-l...
# 1  ['https://images.asos-media.com/products/new-l...
# 2  ['https://images.asos-media.com/products/new-l...
# 3  ['https://images.asos-media.com/products/new-l...
# 4  ['https://images.asos-media.com/products/strad...

# %%
df.shape
# Out:
# (30845, 9)

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.drop_duplicates(subset=['sku'], inplace=True)
df.shape
# Out:
# (29971, 9)

# %%
extracted_brands = []

for url in df['url']:
    url_parts = url.split('/')
    if len(url_parts) > 3:
        brand = url_parts[3]
        extracted_brands.append(brand)
    else:
        extracted_brands.append(None)

df['brand'] = extracted_brands

# %%
brand_counts = df['brand'].value_counts()
popular_brands = brand_counts[brand_counts > 50]
popular_brands
# Out:
# brand
# asos-design              4697
# topshop                  1518
# asos-curve                994
# miss-selfridge            673
# collusion                 631
#                          ...
# fred-perry                 53
# tammy-girl                 52
# french-connection          52
# wednesdays-girl-curve      52
# pretty-lavish-curve        51
# Name: count, Length: 119, dtype: int64

# %%
top_15_brands = [
    "asos-design",
    "topshop",
    "asos-curve",
    "miss-selfridge",
    "collusion",
    "river-island",
    "monki",
    "bershka",
    "asos-petite",
    "asos-tall",
    "new-look",
    "stradivarius",
    "asos-edition",
    "asyou",
    "adidas-originals"
]

df = df[df["brand"].isin(top_15_brands)]

df["brand"] = (
    df["brand"]
    .str.replace("-", " ", regex=False)
    .str.title()
)

# %%
df.shape
# Out:
# (13257, 10)

# %%
def extract_sizes(row):
    in_stock = []
    out_stock = []
    
    if pd.isna(row):
        return in_stock, out_stock
        
    items = row.split(',')
    
    for item in items:
        match = re.search(r"UK\s*(\d+)", item)
        if match:
            size_val = int(match.group(1))
            
            if "Out of stock" in item:
                out_stock.append(size_val)
            else:
                in_stock.append(size_val)
                
    return in_stock, out_stock

df[['in_stock_size', 'out_stock_size']] = df['size'].apply(lambda x: pd.Series(extract_sizes(x)))

df[['size', 'in_stock_size', 'out_stock_size']].head()
# Out:
#                                                  size  \
# 0   UK 4,UK 6,UK 8,UK 10,UK 12,UK 14 - Out of stoc...
# 4   XS - UK 6,S - UK 8,M - UK 10,L - UK 12,XL - UK 14
# 8   3XL - UK 18 - Out of stock,XS - UK 6,S - UK 8,...
# 10  XS - UK 4-6,S - UK 8-10,M - UK 12-14,L - UK 16...
# 14  UK 4,UK 6,UK 8,UK 10,UK 12,UK 14,UK 16,UK 18,U...
#
#                         in_stock_size out_stock_size
# 0           [4, 6, 8, 10, 12, 16, 18]           [14]
# 4                  [6, 8, 10, 12, 14]             []
# 8                  [6, 8, 10, 12, 14]       [18, 16]
# 10                 [4, 8, 12, 16, 20]             []
# 14  [4, 6, 8, 10, 12, 14, 16, 18, 20]             []

# %%
df.drop(columns=['url', 'size', 'category'], inplace=True)

# %%
df.head()
# Out:
#                                                  name  price    color  \
# 0                       New Look trench coat in camel  49.99  Neutral
# 4      Stradivarius double breasted wool coat in grey  59.99     GREY
# 8                  JDY oversized trench coat in stone  45.00    STONE
# 10                 Nike Running hooded jacket in pink  84.95     Pink
# 14  ASOS DESIGN Tall linen mix trench coat in natural  75.00  Natural
#
#             sku                                        description  \
# 0   126704571.0  [{'Product Details': 'Coats & Jackets by New L...
# 4   123650194.0  [{'Product Details': 'Coats & Jackets by Strad...
# 8   125806824.0  [{'Product Details': 'Coats & Jackets by JDYLo...
# 10  121963507.0  [{'Product Details': 'Coats & Jackets by Nike ...
# 14  123053365.0  [{'Product Details': 'Coats & Jackets by ASOS ...
#
#                                                images         brand  \
# 0   ['https://images.asos-media.com/products/new-l...  Stradivarius
# 4   ['https://images.asos-media.com/products/strad...  Stradivarius
# 8   ['https://images.asos-media.com/products/jdy-o...   Asos Petite
# 10  ['https://images.asos-media.com/products/nike-...       Topshop
# 14  ['https://images.asos-media.com/products/asos-...   Asos Design
#
#                         in_stock_size out_stock_size
# 0           [4, 6, 8, 10, 12, 16, 18]           [14]
# 4                  [6, 8, 10, 12, 14]             []
# 8                  [6, 8, 10, 12, 14]       [18, 16]
# 10                 [4, 8, 12, 16, 20]             []
# 14  [4, 6, 8, 10, 12, 14, 16, 18, 20]             []

# %%
df['price'] = (
    df['price']
      .str.replace(r'\b(from|now)\b', '', regex=True, case=False)
      .str.replace(',', '')
      .str.strip()
      .astype(float)
)

# %%
df['sku'] = df['sku'].astype(int)

# %%
df_small = df[
    [   'sku',
        "brand",
        "name",
        "color",
        "price",
        "in_stock_size",
        "out_stock_size",
        "description",
        "images"
    ]
]

# %%
rows_to_keep = ~((df_small['in_stock_size'] == '[]') & (df_small['out_stock_size'] == '[]'))

df_small = df_small[rows_to_keep]

original_row_count = len(df_small)
new_row_count = len(df_small)
dropped_rows_count = original_row_count - new_row_count

# %%
df_small["color"] = df_small["color"].str.upper()

# %%
df_small
# Out:
#              sku           brand  \
# 0      126704571    Stradivarius
# 4      123650194    Stradivarius
# 8      125806824     Asos Petite
# 10     121963507         Topshop
# 14     123053365     Asos Design
# ...          ...             ...
# 30838  122463785     Asos Design
# 30839  120479167     Asos Design
# 30841    1444255     Asos Design
# 30842  110783769           Asyou
# 30843  116363729  Miss Selfridge
#
#                                                     name         color  price  \
# 0                          New Look trench coat in camel       NEUTRAL  49.99
# 4         Stradivarius double breasted wool coat in grey          GREY  59.99
# 8                     JDY oversized trench coat in stone         STONE  45.00
# 10                    Nike Running hooded jacket in pink          PINK  84.95
# 14     ASOS DESIGN Tall linen mix trench coat in natural       NATURAL  75.00
# ...                                                  ...           ...    ...
# 30838  ASOS DESIGN cotton shirred maxi smock dress in...         MULTI  44.00
# 30839  ASOS DESIGN satin midi dress with cowl neck an...     CHOCOLATE  55.00
# 30841  ASOS DESIGN long sleeve maxi t-shirt dress in ...         BLACK  24.00
# 30842  ASYOU layered t-shirt dress with focus graphic...  WASHED BLACK  22.99
# 30843  Miss Selfridge Petite rib knit frill hem funne...         BLACK  32.99
#
#                            in_stock_size  \
# 0              [4, 6, 8, 10, 12, 16, 18]
# 4                     [6, 8, 10, 12, 14]
# 8                     [6, 8, 10, 12, 14]
# 10                    [4, 8, 12, 16, 20]
# 14     [4, 6, 8, 10, 12, 14, 16, 18, 20]
# ...                                  ...
# 30838                                [8]
# 30839                                [8]
# 30841                               [10]
# 30842                                [6]
# 30843                               [10]
#
#                                out_stock_size  \
# 0                                        [14]
# 4                                          []
# 8                                    [18, 16]
# 10                                         []
# 14                                         []
# ...                                       ...
# 30838              [4, 6, 10, 12, 14, 16, 18]
# 30839              [4, 6, 10, 12, 14, 16, 18]
# 30841               [4, 6, 8, 12, 14, 16, 18]
# 30842  [4, 8, 10, 12, 14, 16, 18, 20, 22, 24]
# 30843                   [4, 6, 8, 12, 14, 16]
#
#                                              description  \
# 0      [{'Product Details': 'Coats & Jackets by New L...
# 4      [{'Product Details': 'Coats & Jackets by Strad...
# 8      [{'Product Details': 'Coats & Jackets by JDYLo...
# 10     [{'Product Details': 'Coats & Jackets by Nike ...
# 14     [{'Product Details': 'Coats & Jackets by ASOS ...
# ...                                                  ...
# 30838  [{'Product Details': 'Dresses by ASOS DESIGNTh...
# 30839  [{'Product Details': 'Dresses by ASOS DESIGNAl...
# 30841  [{'Product Details': 'Dress by ASOS DESIGN Act...
# 30842  [{'Product Details': 'Dress by ASYOU Exclusive...
# 30843  [{'Product Details': 'Petite by Miss Selfridge...
#
#                                                   images
# 0      ['https://images.asos-media.com/products/new-l...
# 4      ['https://images.asos-media.com/products/strad...
# 8      ['https://images.asos-media.com/products/jdy-o...
# 10     ['https://images.asos-media.com/products/nike-...
# 14     ['https://images.asos-media.com/products/asos-...
# ...                                                  ...
# 30838  ['https://images.asos-media.com/products/asos-...
# 30839  ['https://images.asos-media.com/products/asos-...
# 30841  ['https://images.asos-media.com/products/asos-...
# 30842  ['https://images.asos-media.com/products/asyou...
# 30843  ['https://images.asos-media.com/products/miss-...
#
# [13257 rows x 9 columns]

# %%
df_small.to_csv("products_small.csv", index=False)
